# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/tmdb_5000_movies.csv', index_col='original_title')
df.head()
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# Spectre                                   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# The Dark Knight Rises                     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# John Carter                               [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
# ...

# %%
df1 = df.drop(columns=['genres','keywords','production_companies','spoken_languages','production_countries'])

# %%
df1.head()
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
#
#                                                                               homepage  \
# original_title
# Avatar                                                     http://www.avatarmovie.com/
# Pirates of the Caribbean: At World's End  http://disney.go.com/disneypictures/pirates/
# Spectre                                    http://www.sonypictures.com/movies/spectre/
# The Dark Knight Rises                               http://www.thedarkknightrises.com/
# John Carter                                       http://movies.disney.com/john-carter
#
#                                               id original_language  \
# original_title
# ...

# %%
df1.isna().any()
# Out:
# budget               False
# homepage              True
# id                   False
# original_language    False
# overview              True
# popularity           False
# release_date          True
# revenue              False
# runtime               True
# status               False
# tagline               True
# title                False
# vote_average         False
# vote_count           False
# dtype: bool

# %%
df1.isna().sum()
# Out:
# budget                  0
# homepage             3091
# id                      0
# original_language       0
# overview                3
# popularity              0
# release_date            1
# revenue                 0
# runtime                 2
# status                  0
# tagline               844
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
df1['homepage'].isna()
# Out:
# original_title
# Avatar                                      False
# Pirates of the Caribbean: At World's End    False
# Spectre                                     False
# The Dark Knight Rises                       False
# John Carter                                 False
#                                             ...
# El Mariachi                                  True
# Newlyweds                                    True
# Signed, Sealed, Delivered                   False
# Shanghai Calling                            False
# My Date with Drew                            True
# Name: homepage, Length: 4803, dtype: bool

# %%
df1.isna().sum().plot(kind='bar')
plt.show()

# %%
df1.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
df1[['budget','popularity','revenue','vote_average']].hist()
plt.show()

# %%
#list of dictionaries by row

list_of_dicts = [
    {'name':'Ginger', 'breed':'Chowchow','height_cm':22, 'weight_kg':10, 'date_of_birth':'2019-09-15'},
    {'name':'Danny', 'breed':'Poodle','height_cm':50, 'weight_kg':25, 'date_of_birth':'2018-05-20'}]

# %%
new_dogs=pd.DataFrame(list_of_dicts)
new_dogs
# Out:
#      name     breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Chowchow         22         10    2019-09-15
# 1   Danny    Poodle         50         25    2018-05-20

# %%
# Dictionary of lists by column
dict_of_list ={'first_name':['Sasha','Casey','Chloe','Danny'],
              'year_of_birth':['1988','1989','2016','2018'],
              'last_name':['Gang','Rowley','Rowley','the dog']}

# %%
family_info = pd.DataFrame(dict_of_list)
family_info
# Out:
#   first_name year_of_birth last_name
# 0      Sasha          1988      Gang
# 1      Casey          1989    Rowley
# 2      Chloe          2016    Rowley
# 3      Danny          2018   the dog

# %%
cal_df = pd.read_csv('data/Food_calories.csv')

# %%
cal_df.head()
# Out:
#         Food              Serving Calories
# 0  Artichoke  1 artichoke (128 g)   60 cal
# 1    Arugula         1 leaf (2 g)    1 cal
# 2  Asparagus       1 spear (12 g)    2 cal
# 3  Aubergine  1 aubergine (458 g)  115 cal
# 4   Beetroot        1 beet (82 g)   35 cal

# %%
chars_to_remove = ['cal']

for char in chars_to_remove:
    cal_df['Calories'] = cal_df['Calories'].astype(str).str.replace(char,'')
    # Convert col to numeric
    cal_df['Calories'] = pd.to_numeric(cal_df['Calories'])

# %%
cal_df.head()
# Out:
#         Food              Serving  Calories
# 0  Artichoke  1 artichoke (128 g)        60
# 1    Arugula         1 leaf (2 g)         1
# 2  Asparagus       1 spear (12 g)         2
# 3  Aubergine  1 aubergine (458 g)       115
# 4   Beetroot        1 beet (82 g)        35

# %%
cal_df.to_csv('foodcalories.csv')

# %%
cal_df['Calories'].describe()
# Out:
# count     562.000000
# mean      229.669039
# std       232.303786
# min         1.000000
# 25%        70.000000
# 50%       160.500000
# 75%       328.500000
# max      2209.000000
# Name: Calories, dtype: float64

# %%
cal_df.loc[cal_df['Calories'] ==cal_df['Calories'].max()]
# Out:
#                 Food             Serving  Calories
# 132  Chicken Marsala  1 serving (2301 g)      2209

# %%
cal_df['Food'].unique()
# Out:
# array(['Artichoke', 'Arugula', 'Asparagus', 'Aubergine', 'Beetroot',
#        'Bell Pepper', 'Black Olives', 'Broccoli', 'Brussels Sprouts',
#        'Cabbage', 'Capsicum', 'Carrot', 'Cauliflower', 'Celery', 'Chard',
#        'Cherry Tomato', 'Chicory', 'Chinese Cabbage', 'Chives',
#        'Collard Greens', 'Corn', 'Courgette', 'Creamed Spinach',
#        'Cucumber', 'Eggplant', 'Endive', 'Fennel', 'Garlic', 'Gherkin',
#        'Gourd', 'Green Beans', 'Green Olives', 'Green Onion',
#        'Horseradish', 'Kale', 'Kohlrabi', 'Kumara', 'Leek', 'Lettuce',
#        'Mushrooms', 'Mustard Greens', 'Nori', 'Okra', 'Olives', 'Onion',
#        'Parsnips', 'Peas', 'Pepper', 'Potato', 'Pumpkin', 'Radishes',
#        'Red Cabbage', 'Rutabaga', 'Shallots', 'Spinach', 'Squash',
#        'Sweet Potato', 'Tomato', 'Turnip Greens', 'Turnips', 'Wasabi',
#        'Winter Squash', 'Zucchini', 'Acai', 'Apple', 'Applesauce',
#        'Apricot', 'Avocado', 'Banana', 'Blackberries', 'Blood Oranges',
# ...

# %%
cal_df.set_index('Food', inplace=True)

# %%
cal_df.head()
# Out:
#                        Serving  Calories
# Food
# Artichoke  1 artichoke (128 g)        60
# Arugula           1 leaf (2 g)         1
# Asparagus       1 spear (12 g)         2
# Aubergine  1 aubergine (458 g)       115
# Beetroot         1 beet (82 g)        35

# %%
cal_df.reset_index(inplace=True)

# %%
cal_df[cal_df.Food.isin(['Burger', 'Pizza', 'Sandwich',
                                            'McDonald’s', 'Nuggets', 'Wendy’s'])]
# Out:
#       Food          Serving  Calories
# 172  Pizza  1 slice (102 g)       272

# %%
cal_df.plot(kind='line')

# %%
cal_under_30 = cal_df[cal_df['Calories'] <=30]
cal_under_30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75 entries, 1 to 551
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Food      75 non-null     object
#  1   Serving   75 non-null     object
#  2   Calories  75 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 2.3+ KB

# %%
plt.scatter(x='Food', y='Calories', data=cal_under_30)

# %%
cal_df
# Out:
#                          Food  Serving  Calories
# 0                   Artichoke   128 g)        60
# 1                     Arugula     2 g)         1
# 2                   Asparagus    12 g)         2
# 3                   Aubergine   458 g)       115
# 4                    Beetroot    82 g)        35
# ..                        ...      ...       ...
# 557  Wendy’s Jr. Cheeseburger   129 g)       290
# 558  Wendy’s Son of Baconator   218 g)       700
# 559                   Whopper   291 g)       672
# 560                    Zinger   202 g)       517
# 561             Zinger Burger   202 g)       517
#
# [562 rows x 3 columns]

# %%
cal_df['Serving'].sample(10)
# Out:
# 344                    103 g)
# 320                    241 g)
# 77     1 custard apple 135 g)
# 85             1 oz. 28.35 g)
# 35          1 kohlrabi 400 g)
# 368               2 oz. 56 g)
# 501                    219 g)
# 22                     200 g)
# 222               1 oz. 28 g)
# 343           1 sundae 178 g)
# Name: Serving, dtype: object

# %%
chars_to_remove = [' g)']

for char in chars_to_remove:
    cal_df['Serving'] = cal_df['Serving'].astype(str).str.replace(char,'')
    # Convert col to numeric
    #cal_df['Calories'] = pd.to_numeric(cal_df['Calories'])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-101-ae3a905a18c3> in <module>
#       2
#       3 for char in chars_to_remove:
# ----> 4     cal_df['Serving'] = cal_df['Serving'].astype(str).str.replace(char,'')
#       5     # Convert col to numeric
#       6     #cal_df['Calories'] = pd.to_numeric(cal_df['Calories'])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py in wrapper(self, *args, **kwargs)
#    1952                 )
#    1953                 raise TypeError(msg)
# -> 1954             return func(self, *args, **kwargs)
#    1955
#    1956         wrapper.__name__ = func_name
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py in replace(self, pat, repl, n, case, flags, regex)
#    2774     @forbid_nonstring_types(["bytes"])
#    2775     def replace(self, pat, repl, n=-1, case=None, flags=0, regex=True):
# ...

# %%
chars_to_remove = ['1 artichoke','1 leaf','1 spear','1 aubergine','1 beet','1 burger','1 sandwich']
for char in chars_to_remove:
    cal_df['Serving'] = cal_df['Serving'].astype(str).str.replace(char,'')

# %%
cal_df['Serving'].unique()
# Out:
# array([' (128 g)', ' (2 g)', ' (12 g)', ' (458 g)', ' (82 g)',
#        '1 pepper (73 g)', '1 olive (2.7 g)', '1 bunch (608 g)',
#        '1 sprout (19 g)', '1 head (908 g)', '1 pepper (45 g)',
#        '1 carrot (61 g)', '1 floweret (13 g)', '1 stalk (40 g)',
#        ' (48 g)', '1 cherry tomato (20 g)', '1 head (53 g)',
#        '1 head (840 g)', '1 tbsp, chopped (3 g)', ', raw (36 g)',
#        ' (154 g)', '1 courgette (196 g)', ' (200 g)',
#        '1 cucumber (410 g)', '1 eggplant (458 g)', '1 head (513 g)',
#        '1 bulb (234 g)', '1 clove (3 g)', '1 gherkin (65 g)',
#        '1 gourd (771 g)', ' (110 g)', '1 green onion (15 g)',
#        '1 tbsp (15 g)', ', chopped (67 g)', '1 kohlrabi (400 g)',
#        '1 kumara (130 g)', '1 leek (89 g)', '1 head (600 g)',
#        '1 mushroom (5.4 g)', ', chopped (56 g)', '1 sheet (2.6 g)',
#        '1 pod (12 g)', '1 onion (85 g)', '1 parsnip (170 g)', ' (98 g)',
#        '1 pepper (75 g)', '1 potato (213 g)', '1 pumpkin (196 g)',
# ...

# %%
chars_to_keep = ['(','g)']

for x in set(cal_df['Serving']).difference(chars_to_keep):
    cal_df['Serving'] = cal_df['Serving'].astype(str).str.replace(x,'')

# %%
cal_df['Serving'].unique()
# Out:
# array([' (128 g)', ' (2 g)', ' (12 g)', ' (458 g)', ' (82 g)',
#        '1 pepper (73 g)', '1 olive (2.7 g)', '1 bunch (608 g)',
#        '1 sprout (19 g)', '1 head (908 g)', '1 pepper (45 g)',
#        '1 carrot (61 g)', '1 floweret (13 g)', '1 stalk (40 g)',
#        ' (48 g)', '1 cherry tomato (20 g)', '1 head (53 g)',
#        '1 head (840 g)', '1 tbsp, chopped (3 g)', ', raw (36 g)',
#        ' (154 g)', '1 courgette (196 g)', ' (200 g)',
#        '1 cucumber (410 g)', '1 eggplant (458 g)', '1 head (513 g)',
#        '1 bulb (234 g)', '1 clove (3 g)', '1 gherkin (65 g)',
#        '1 gourd (771 g)', ' (110 g)', '1 green onion (15 g)',
#        '1 tbsp (15 g)', ', chopped (67 g)', '1 kohlrabi (400 g)',
#        '1 kumara (130 g)', '1 leek (89 g)', '1 head (600 g)',
#        '1 mushroom (5.4 g)', ', chopped (56 g)', '1 sheet (2.6 g)',
#        '1 pod (12 g)', '1 onion (85 g)', '1 parsnip (170 g)', ' (98 g)',
#        '1 pepper (75 g)', '1 potato (213 g)', '1 pumpkin (196 g)',
# ...

# %%
cal_df['Serving'] = pd.to_numeric(cal_df['Serving'],errors='ignore')

# %%
cal_df['Serving'].dtype
# Out:
# dtype('O')

# %%
cal_df['Serving']=cal_df['Serving'].replace("(","")
cal_df['Serving']=cal_df['Serving'].replace("g)","")

# %%
cal_df['Serving']=cal_df['Serving'].replace("1 pepper","")
cal_df['Serving']=cal_df['Serving'].replace("1 wrap","")
cal_df['Serving']=cal_df['Serving'].replace("1 wing","")

# %%
cal_df['Serving']=cal_df['Serving'].replace("1 mcflurry","")
cal_df['Serving']=cal_df['Serving'].replace("1 cookie","")
cal_df['Serving']=cal_df['Serving'].replace("1 cracker","")
cal_df['Serving']=cal_df['Serving'].replace("1 fruit","")
cal_df['Serving']=cal_df['Serving'].replace("1 tbsp","")
